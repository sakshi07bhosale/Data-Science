# %%
#create dataset and print it
import pandas as pd 
import numpy as np 
data = {
    "Name":["A","B","C","D","E","A"],
    "Marks":[85,None,90,60,None,85],
    "Age":[20,21,None,222,23,20],
    "City":["Mumbai","Pune","Mumbai",None,"Delhi","Mumbai"]

}
df = pd.DataFrame(data)
print("Original Data:\n",df)
# Out:
# Original Data:
#    Name  Marks    Age    City
# 0    A   85.0   20.0  Mumbai
# 1    B    NaN   21.0    Pune
# 2    C   90.0    NaN  Mumbai
# 3    D   60.0  222.0     NaN
# 4    E    NaN   23.0   Delhi
# 5    A   85.0   20.0  Mumbai

# %%
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Name     0
# Marks    2
# Age      1
# City     1
# dtype: int64

# %%
print("\nDuplicates:", df.duplicated().sum())
# Out:
# Duplicates: 1

# %%
df.drop_duplicates(inplace=True)
print(df)
# Out:
#   Name  Marks    Age    City
# 0    A   85.0   20.0  Mumbai
# 1    B    NaN   21.0    Pune
# 2    C   90.0    NaN  Mumbai
# 3    D   60.0  222.0     NaN
# 4    E    NaN   23.0   Delhi

# %%
# Fill Marks with mean
df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6180\1768294232.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# 0    85.000000
# 1    78.333333
# 2    90.000000
# 3    60.000000
# 4    78.333333
# Name: Marks, dtype: float64

# %%
# Fill Age with median
df["Age"].fillna(df["Age"].median(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6180\3881770384.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# 0     20.0
# 1     21.0
# 2     22.0
# 3    222.0
# 4     23.0
# Name: Age, dtype: float64

# %%
# Fill City with mode 
df["City"].fillna(df["City"].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6180\197781458.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["City"].fillna(df["City"].mode()[0], inplace=True)
# 0    Mumbai
# 1      Pune
# 2    Mumbai
# 3    Mumbai
# 4     Delhi
# Name: City, dtype: str
