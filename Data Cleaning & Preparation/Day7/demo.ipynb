# %%
#create data
import pandas as pd
import numpy as np

data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [80, np.nan, 90, None],
    "Age": [20, 21, None, 22]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks   Age
# 0    A   80.0  20.0
# 1    B    NaN  21.0
# 2    C   90.0   NaN
# 3    D    NaN  22.0

# %%
#Check Missing Values
print(df.isnull())        # shows True/False
# Out:
#     Name  Marks    Age
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False   True  False
