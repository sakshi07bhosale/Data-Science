# %%
import pandas as pd

# ✅ Correct file path (IMPORTANT)
df = pd.read_csv("Student_dataset.csv")

# %%
import pandas as pd
df = pd.read_csv("Student_dataset.csv")
print(df.head())
# Out:
#         Name  Marks   Age       City
# 0  Student_1   78.0  18.0  Bangalore
# 1  Student_2   91.0  24.0     Mumbai
# 2  Student_3   68.0   NaN      Delhi
# 3  Student_4    NaN  23.0  Bangalore
# 4  Student_5   82.0  22.0  Bangalore

# %%
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Name      0
# Marks    20
# Age      15
# City     10
# dtype: int64

# %%
print("\nDuplicates:", df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
# Fill Marks with mean
df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27004\663916018.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# 0      78.000000
# 1      91.000000
# 2      68.000000
# 3      69.561538
# 4      82.000000
#          ...
# 145    46.000000
# 146    48.000000
# 147    69.561538
# 148    51.000000
# 149    73.000000
# Name: Marks, Length: 150, dtype: float64

# %%
# Fill Age with median
df["Age"].fillna(df["Age"].median(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27004\3881770384.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# 0      18.0
# 1      24.0
# 2      21.0
# 3      23.0
# 4      22.0
#        ...
# 145    18.0
# 146    18.0
# 147    21.0
# 148    21.0
# 149    23.0
# Name: Age, Length: 150, dtype: float64

# %%
# Fill City with mode (most common)
df["City"].fillna(df["City"].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27004\2044329476.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["City"].fillna(df["City"].mode()[0], inplace=True)
# 0      Bangalore
# 1         Mumbai
# 2          Delhi
# 3      Bangalore
# 4      Bangalore
#          ...
# 145    Bangalore
# 146    Bangalore
# 147       Mumbai
# 148         Pune
# 149       Mumbai
# Name: City, Length: 150, dtype: str

# %%
print("\nAfter Cleaning:\n", df.isnull().sum())
# Out:
# After Cleaning:
#  Name      0
# Marks    20
# Age      15
# City     10
# dtype: int64

# %%
# Add Result column
df["Result"] = df["Marks"].apply(lambda x: "Pass" if x >= 75 else "Fail")
print(df)
# Out:
#             Name  Marks   Age       City Result
# 0      Student_1   78.0  18.0  Bangalore   Pass
# 1      Student_2   91.0  24.0     Mumbai   Pass
# 2      Student_3   68.0   NaN      Delhi   Fail
# 3      Student_4    NaN  23.0  Bangalore   Fail
# 4      Student_5   82.0  22.0  Bangalore   Pass
# ..           ...    ...   ...        ...    ...
# 145  Student_146   46.0  18.0  Bangalore   Fail
# 146  Student_147   48.0  18.0        NaN   Fail
# 147  Student_148    NaN  21.0     Mumbai   Fail
# 148  Student_149   51.0   NaN       Pune   Fail
# 149  Student_150   73.0  23.0     Mumbai   Fail
#
# [150 rows x 5 columns]

# %%
print("\nCleaned Data:\n", df)
# Out:
# Cleaned Data:
#              Name  Marks   Age       City Result
# 0      Student_1   78.0  18.0  Bangalore   Pass
# 1      Student_2   91.0  24.0     Mumbai   Pass
# 2      Student_3   68.0   NaN      Delhi   Fail
# 3      Student_4    NaN  23.0  Bangalore   Fail
# 4      Student_5   82.0  22.0  Bangalore   Pass
# ..           ...    ...   ...        ...    ...
# 145  Student_146   46.0  18.0  Bangalore   Fail
# 146  Student_147   48.0  18.0        NaN   Fail
# 147  Student_148    NaN  21.0     Mumbai   Fail
# 148  Student_149   51.0   NaN       Pune   Fail
# 149  Student_150   73.0  23.0     Mumbai   Fail
#
# [150 rows x 5 columns]

# %%
print("\nAverage Marks:", df["Marks"].mean())
# Out:
# Average Marks: 69.56153846153846

# %%
print("\nMarks by City:\n", df.groupby("City")["Marks"].mean())
# Out:
# Marks by City:
#  City
# Bangalore    66.386364
# Delhi        69.695652
# Mumbai       70.379310
# Pune         73.416667
# Name: Marks, dtype: float64
