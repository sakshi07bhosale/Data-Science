# %%
import pandas as pd 
df = pd.read_csv("Student_dataset.csv")

# %%
#Basic Feature Creation
#result column
import pandas as pd 
df = pd.read_csv("Student_dataset.csv")
df["Result"] = df["Marks"].apply(lambda x: "Pass" if x >= 75 else "Fail")
print(df)
# Out:
#             Name  Marks   Age       City Result
# 0      Student_1   78.0  18.0  Bangalore   Pass
# 1      Student_2   91.0  24.0     Mumbai   Pass
# 2      Student_3   68.0   NaN      Delhi   Fail
# 3      Student_4    NaN  23.0  Bangalore   Fail
# 4      Student_5   82.0  22.0  Bangalore   Pass
# ..           ...    ...   ...        ...    ...
# 145  Student_146   46.0  18.0  Bangalore   Fail
# 146  Student_147   48.0  18.0        NaN   Fail
# 147  Student_148    NaN  21.0     Mumbai   Fail
# 148  Student_149   51.0   NaN       Pune   Fail
# 149  Student_150   73.0  23.0     Mumbai   Fail
#
# [150 rows x 5 columns]

# %%
#add gradde column
def grade(x):
    if x >= 85:
        return "A"
    elif x >= 70:
        return "B"
    else:
        return "C"
df["Grade"] = df["Marks"].apply(grade)
print(df)
# Out:
#             Name  Marks   Age       City Result Gradee Grade
# 0      Student_1   78.0  18.0  Bangalore   Pass      B     B
# 1      Student_2   91.0  24.0     Mumbai   Pass      A     A
# 2      Student_3   68.0   NaN      Delhi   Fail      C     C
# 3      Student_4    NaN  23.0  Bangalore   Fail      C     C
# 4      Student_5   82.0  22.0  Bangalore   Pass      B     B
# ..           ...    ...   ...        ...    ...    ...   ...
# 145  Student_146   46.0  18.0  Bangalore   Fail      C     C
# 146  Student_147   48.0  18.0        NaN   Fail      C     C
# 147  Student_148    NaN  21.0     Mumbai   Fail      C     C
# 148  Student_149   51.0   NaN       Pune   Fail      C     C
# 149  Student_150   73.0  23.0     Mumbai   Fail      B     B
#
# [150 rows x 7 columns]

# %%
#Binning (Grouping Values)
df["Marks_Category"] = pd.cut(df["Marks"],
                             bins=[0, 60, 80, 100],
                             labels=["Low", "Medium", "High"])
print(df)
# Out:
#             Name  Marks   Age       City Result Gradee Grade Marks_Category
# 0      Student_1   78.0  18.0  Bangalore   Pass      B     B         Medium
# 1      Student_2   91.0  24.0     Mumbai   Pass      A     A           High
# 2      Student_3   68.0   NaN      Delhi   Fail      C     C         Medium
# 3      Student_4    NaN  23.0  Bangalore   Fail      C     C            NaN
# 4      Student_5   82.0  22.0  Bangalore   Pass      B     B           High
# ..           ...    ...   ...        ...    ...    ...   ...            ...
# 145  Student_146   46.0  18.0  Bangalore   Fail      C     C            Low
# 146  Student_147   48.0  18.0        NaN   Fail      C     C            Low
# 147  Student_148    NaN  21.0     Mumbai   Fail      C     C            NaN
# 148  Student_149   51.0   NaN       Pune   Fail      C     C            Low
# 149  Student_150   73.0  23.0     Mumbai   Fail      B     B         Medium
#
# [150 rows x 8 columns]
