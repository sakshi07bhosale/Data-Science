# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data = {
    "Age": [18, 19, 20, 21, 22],
    "Marks": [60, 65, 70, 75, 80]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Age  Marks
# 0   18     60
# 1   19     65
# 2   20     70
# 3   21     75
# 4   22     80

# %%
#Define X and y
x=df[["Age"]]
y=df["Marks"]
print(x)
print(y)
# Out:
#    Age
# 0   18
# 1   19
# 2   20
# 3   21
# 4   22
# 0    60
# 1    65
# 2    70
# 3    75
# 4    80
# Name: Marks, dtype: int64

# %%
#Train Model
model = LinearRegression()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Train Model
# ----> 2 model = LinearRegression()
#       3 model.fit(X, y)
#
# NameError: name 'LinearRegression' is not defined

# %%
#predict
pred = model.predict([[23]])
print("Predicted Marks for Age 23:", pred[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #predict
# ----> 2 pred = model.predict([[23]])
#       3 print("Predicted Marks for Age 23:", pred[0])
#
# NameError: name 'model' is not defined

# %%
#add gradde column
def grade(x):
    if x >= 85:
        return "A"
    elif x >= 70:
        return "B"
    else:
        return "C"
df["Grade"] = df["Marks"].apply(grade)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7     else:
#       8         return "C"
# ----> 9 df["Grade"] = df["Marks"].apply(grade)
#      10 print(df)
#
# NameError: name 'df' is not defined
