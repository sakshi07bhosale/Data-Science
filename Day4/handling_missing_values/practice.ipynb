# %%
#Count missing values
#Fill missing values with mean

import pandas as pd 
data = {
    "Marks" : [50,None,70,None,90]
}
df = pd.DataFrame(data)

#1 count missing values
print("Missing values:")
print(df.isnull().sum())

#2 fill with mean 
df["Marks"].fillna(df["Marks"].mean(),inplace=True)

print("\n Updated Data:")
print(df)
# Out:
# Missing values:
# Marks    2
# dtype: int64
#
#  Updated Data:
#    Marks
# 0   50.0
# 1    NaN
# 2   70.0
# 3    NaN
# 4   90.0
# C:\Users\hp\AppData\Local\Temp\ipykernel_3876\2678947566.py:15: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(),inplace=True)

# %%
#Fill missing values with 25
#Print updated data

import pandas as pd

data = {
    "Age": [20, 21, None, 22, None]
}

df = pd.DataFrame(data)

# Fill missing values with 25
df["Age"].fillna(25, inplace=True)

print(df)
# Out:
#     Age
# 0  20.0
# 1  21.0
# 2   NaN
# 3  22.0
# 4   NaN
# C:\Users\hp\AppData\Local\Temp\ipykernel_3876\3774922351.py:13: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(25, inplace=True)
