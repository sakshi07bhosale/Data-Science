# %%
#Series (1D Data)
import pandas as pd

s = pd.Series([10, 20, 30])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#DataFrame (Table / 2D Data)
data={
    "Name":["A","B","C"],
    "Marks":[80,90,70]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks
# 0    A     80
# 1    B     90
# 2    C     70
