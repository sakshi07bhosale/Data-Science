# %%
data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [60, 75, 90, 50],
    "City": ["Mumbai", "Pune", "Mumbai", "Delhi"]
}

# %%
import pandas as pd

# Create data
data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [60, 75, 90, 50],
    "City": ["Mumbai", "Pune", "Mumbai", "Delhi"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks    City
# 0    A     60  Mumbai
# 1    B     75    Pune
# 2    C     90  Mumbai
# 3    D     50   Delhi
