# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["A", "B", "C", "D", "E", "F"],
    "Marks": [85, 70, None, 60, 90, None],
    "Age": [20, 21, 19, None, 22, 20],
    "City": ["Mumbai", "Pune", "Mumbai", "Delhi", "Pune", "Mumbai"]
}

df = pd.DataFrame(data)

# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["A", "B", "C", "D", "E", "F"],
    "Marks": [85, 70, None, 60, 90, None],
    "Age": [20, 21, 19, None, 22, 20],
    "City": ["Mumbai", "Pune", "Mumbai", "Delhi", "Pune", "Mumbai"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks   Age    City
# 0    A   85.0  20.0  Mumbai
# 1    B   70.0  21.0    Pune
# 2    C    NaN  19.0  Mumbai
# 3    D   60.0   NaN   Delhi
# 4    E   90.0  22.0    Pune
# 5    F    NaN  20.0  Mumbai

# %%
# Fill missing values
df["Marks"].fillna(df["Marks"].mean(), inplace=True)
df["Age"].fillna(df["Age"].median(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5900\1311607775.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# ...

# %%
# Add Result column
df["Result"] = df["Marks"].apply(lambda x: "Pass" if x >= 75 else "Fail")
print(df)
# Out:
#   Name  Marks   Age    City Result
# 0    A   85.0  20.0  Mumbai   Pass
# 1    B   70.0  21.0    Pune   Fail
# 2    C    NaN  19.0  Mumbai   Fail
# 3    D   60.0   NaN   Delhi   Fail
# 4    E   90.0  22.0    Pune   Pass
# 5    F    NaN  20.0  Mumbai   Fail

# %%
#Analysis
print("Average Marks:", df["Marks"].mean())
print("\nMarks by City:\n", df.groupby("City")["Marks"].mean())
# Out:
# Average Marks: 76.25
#
# Marks by City:
#  City
# Delhi     60.0
# Mumbai    85.0
# Pune      80.0
# Name: Marks, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1️⃣ Bar Chart (Marks by Student)
plt.figure()
sns.barplot(x="Name", y="Marks", data=df)
plt.title("Marks by Student")
plt.show()

# %%
# 2️⃣ Count Plot (City Distribution)
plt.figure()
sns.countplot(x="City", data=df)
plt.title("Students by City")
plt.show()

# %%
# 3️⃣ Box Plot (Marks Distribution)
plt.figure()
sns.boxplot(y=df["Marks"])
plt.title("Marks Distribution")
plt.show()

# %%
# 4️⃣ Histogram
plt.figure()
plt.hist(df["Marks"])
plt.title("Marks Frequency")
plt.show()
