# %%
import pandas as pd

df = pd.read_csv("Student_dataset.csv")

# %%
df["Marks"].fillna(df["Marks"].mean(), inplace=True)
df["Age"].fillna(df["Age"].median(), inplace=True)
df["City"].fillna(df["City"].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20156\1409530084.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_20156\1409530084.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_20156\1409530084.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["City"].fillna(df["City"].mode()[0], inplace=True)
# 0      Bangalore
# 1         Mumbai
# 2          Delhi
# 3      Bangalore
# 4      Bangalore
#          ...
# 145    Bangalore
# 146    Bangalore
# 147       Mumbai
# 148         Pune
# 149       Mumbai
# Name: City, Length: 150, dtype: str

# %%
print(df.describe())
# Out:
#             Marks         Age
# count  130.000000  135.000000
# mean    69.561538   21.007407
# std     18.068776    2.100093
# min     40.000000   18.000000
# 25%     54.000000   19.000000
# 50%     68.000000   21.000000
# 75%     83.750000   23.000000
# max     99.000000   24.000000

# %%
print(df.head())
# Out:
#         Name  Marks   Age       City
# 0  Student_1   78.0  18.0  Bangalore
# 1  Student_2   91.0  24.0     Mumbai
# 2  Student_3   68.0   NaN      Delhi
# 3  Student_4    NaN  23.0  Bangalore
# 4  Student_5   82.0  22.0  Bangalore

# %%
print("Min:", df["Marks"].min())
print("Max:", df["Marks"].max())
print("Range:", df["Marks"].max() - df["Marks"].min())
# Out:
# Min: 40.0
# Max: 99.0
# Range: 59.0

# %%
print("Standard Deviation:", df["Marks"].std())
# Out:
# Standard Deviation: 18.068776377644696

# %%
print(df.groupby("City")["Marks"].mean())
# Out:
# City
# Bangalore    66.386364
# Delhi        69.695652
# Mumbai       70.379310
# Pune         73.416667
# Name: Marks, dtype: float64

# %%
print(df["City"].value_counts())
# Out:
# City
# Bangalore    51
# Delhi        32
# Mumbai       31
# Pune         26
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Histogram
plt.hist(df["Marks"])
plt.title("Marks Distribution")
plt.show()

# %%
# Boxplot
plt.boxplot(df["Marks"])
plt.title("Marks Spread")
plt.show()
