# %%
import pandas as pd

data = {
    "Marks": [50, 60, 70, 80, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Marks
# 0     50
# 1     60
# 2     70
# 3     80
# 4     90

# %%
#mean
print(df["Marks"].mean())
# Out:
# 70.0

# %%
#median
print(df["Marks"].median())
# Out:
# 70.0
