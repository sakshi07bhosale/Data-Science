# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame({
    "Hours": [1,2,3,4,5],
    "Marks": [20,40,50,70,90]
})

print(df)
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     40
# 2      3     50
# 3      4     70
# 4      5     90
