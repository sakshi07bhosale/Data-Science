# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
#Create Dataset

df = pd.DataFrame({
    "Hours": [1,2,3,4,5,6],
    "Result": [0,0,0,1,1,1]
})

print(df)
# Out:
#    Hours  Result
# 0      1       0
# 1      2       0
# 2      3       0
# 3      4       1
# 4      5       1
# 5      6       1

# %%
#Input & Output

X = df[["Hours"]]
y = df["Result"]

# %%
#Create Model

model = DecisionTreeClassifier()
