# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#Create Dataset


df = pd.DataFrame({
    "Hours": [1,2,3,8,9,10],
    "Marks": [20,25,30,80,85,90]
})

print(df)
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     25
# 2      3     30
# 3      8     80
# 4      9     85
# 5     10     90

# %%
#elect Features

X = df[["Hours", "Marks"]]

# %%
#Create Model


model = KMeans(
    n_clusters=2,
    random_state=42
)
