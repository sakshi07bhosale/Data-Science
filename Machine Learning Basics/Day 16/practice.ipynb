# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# Data
df = pd.DataFrame({
    "Hours": [1, 2, 3, 4, 5],
    "Marks": [20, 40, 50, 70, 90]
})

# %%
#input and output
x=df[["Hours"]]
t=[["Marks"]]
