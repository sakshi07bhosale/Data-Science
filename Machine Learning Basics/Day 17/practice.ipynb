# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Data
df = pd.DataFrame({
    "Hours": [1, 2, 3, 8, 9, 10],
    "Marks": [20, 25, 30, 80, 85, 90]
})

# %%
print(df)
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     25
# 2      3     30
# 3      8     80
# 4      9     85
# 5     10     90

# %%
# Features
X = df[["Hours", "Marks"]]
print(X)
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     25
# 2      3     30
# 3      8     80
# 4      9     85
# 5     10     90

# %%
# Model
model = KMeans(n_clusters=2)

# %%
# Train
model.fit(X)
# Out:
# C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\externals\loky\backend\context.py:131: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\externals\loky\backend\context.py", line 247, in _count_physical_cores
#     cpu_count_physical = _count_physical_cores_win32()
#   File "C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\externals\loky\backend\context.py", line 299, in _count_physical_cores_win32
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 1038, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 1552, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
# KMeans(n_clusters=2)

# %%
# Cluster labels
df["Cluster"] = model.labels_

# %%
print(df)
# Out:
#    Hours  Marks  Cluster
# 0      1     20        0
# 1      2     25        0
# 2      3     30        0
# 3      8     80        1
# 4      9     85        1
# 5     10     90        1

# %%
#Visualization
plt.scatter(df["Hours"], df["Marks"], c=df["Cluster"])

plt.xlabel("Hours")
plt.ylabel("Marks")
plt.title("Student Clusters")

plt.show()

# %%
#Elbow Method Code
wcss = []

for i in range(1, 6):
    model = KMeans(n_clusters=i)
    model.fit(X)
    wcss.append(model.inertia_)

plt.plot(range(1, 6), wcss)
plt.xlabel("Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()
