# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
# Data
df = pd.DataFrame({
    "Hours": [1, 2, 3, 8, 9, 10],
    "Marks": [20, 25, 30, 80, 85, 90]
})

# %%
# Features
X = df[["Hours", "Marks"]]
X
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     25
# 2      3     30
# 3      8     80
# 4      9     85
# 5     10     90
